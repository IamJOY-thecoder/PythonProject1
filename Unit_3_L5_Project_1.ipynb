# %% [markdown]
# <a href="https://colab.research.google.com/github/IamJOY-thecoder/PythonProject1/blob/master/Unit_3_L5_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)
#filter data to show choice school and DBN data, then calculate based on this selection the mean score for the regent exam during periods 2015-2017
df2 = df[(df['School DBN'] == '84R073') & (df['School Name'] == 'New World Preparatory Charter School')] 
#Filter 1
df2 =sns.barplot(x="Mean Score", y="Regents Exam", hue="Year", data=df2, palette="Spectral")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)

#filter 1a the graph shows the mean score for the regent exam during periods 2015-2017 for the entire city
df=sns.barplot(x="Mean Score", y="Regents Exam", hue="Year", data=df, palette="Spectral")
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)
#filter 2 the graph shows the number of students in New World Preparatory Charter Schoold in the year 2017 and the Regents exam they took.

df2 = df[(df['School DBN'] == '84R073') & (df['School Name'] == 'New World Preparatory Charter School') & (df['Year'] == 2017)]
df2
print("")

print(df2.groupby(['Regents Exam'])['Total Tested'].count().sort_values(ascending=False))
print("")

df2 = sns.countplot(y="Regents Exam", data=df2,  palette="Spectral", hue="School Name")
df2
# Out:
# Regents Exam
# Common Core Algebra    10
# Name: Total Tested, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)
#filter 2a the graph shows the number of students who tested in all regents exam types between 2015-2017 in the city.

print(df.groupby(['Regents Exam'])['Total Tested'].count().sort_values(ascending=False))
print("")
sns.countplot(y="Regents Exam", data=df,  palette="Spectral")
# Out:
# Regents Exam
# Common Core Algebra                29254
# Living Environment                 25539
# U.S. History and Government        20426
# Common Core English                19878
# Global History and Geography       19192
# Physical Settings/Earth Science    15971
# Common Core Geometry               15267
# Physical Settings/Chemistry        11670
# English                            11091
# Integrated Algebra                 11022
# Algebra2/Trigonometry              10788
# Geometry                            8509
# Common Core Algebra2                7915
# Physical Settings/Physics           5799
# Name: Total Tested, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)
#Filter 3 shows the mean score of all exam taken across the schools 
sns.distplot(df['Mean Score'], bins=50)

# the graph shows the total tested that scored 65 percent and above 
sns.jointplot(x='Total Tested', y='Percent Scoring 65 or Above', data=df, kind='hex')

# %%
#filter shows the schools with the number of students who scored 80 and above, and the graph shows the regent exam with the highest score, and show the year it occured. 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
missing_values = ['na', 's']

df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)

df1 = df[(df['Number Scoring 80 or Above'] >= 80) & (df['Year'] <= 2017)]
print(df1.groupby(['School Name','Regents Exam', 'Year'])['Number Scoring 80 or Above'].count().sort_values(ascending=False))

print("")

sns.barplot(x="Number Scoring 80 or Above", y='Regents Exam', data=df1,  palette="Spectral", hue='Year')
# Out:
# School Name                                         Regents Exam                 Year
# Brooklyn Technical High School                      U.S. History and Government  2015    11
# Benjamin N. Cardozo High School                     Common Core English          2016    10
# Brooklyn Technical High School                      Common Core English          2017    10
# Benjamin N. Cardozo High School                     Common Core English          2015    10
# Edward R. Murrow High School                        Common Core English          2016    10
#                                                                                          ..
# Queens High School for the Sciences at York Colleg  Living Environment           2017     1
# J.H.S. 074 Nathaniel Hawthorne                      U.S. History and Government  2015     1
#                                                     Living Environment           2015     1
# ...
